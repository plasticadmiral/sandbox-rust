# %%
import numpy as np
from matplotlib import pyplot as plt


# n,m = 2, 2
# plt.plot([n, n+1, n, n], [m, m, m+1, m])
# plt.plot([n+1, n, n+1, n+1], [m+1, m+1, m, m+2])



meshx = np.array([[0,1,0],
         [0,1,1],
         [1,2,1],
         [2,2,1],
         [1,2,2],
         [1,2,1],
         [1,1,0],
         [0,1,0]], dtype=np.uint32)

meshy = np.array([[0,1,1],
         [0,0,1],
         [0,0,1],
         [0,1,1], 
         [1,1,2],
         [1,2,2],
         [1,2,2],
         [1,1,2]], dtype=np.uint32)

meshx = meshx+2
meshy = meshy+2
for x,y in zip(meshx, meshy):
    plt.plot(x, y)

    
meshx = meshx+2
meshy = meshy+2
for x,y in zip(meshx, meshy):
    plt.plot(x, y)

#x = [0.25, 0.75]
#y = [0.75, 1.75]
#plt.scatter(x, y)

plt.grid()

plt.tight_layout()
plt.savefig('grid.png')
plt.show()

# %%
print(np.linalg.inv(meshx))
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(np.linalg.inv(meshx))
#
# File <__array_function__ internals>:200, in inv(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/linalg/linalg.py:533, in inv(a)
#     531 a, wrap = _makearray(a)
#     532 _assert_stacked_2d(a)
# --> 533 _assert_stacked_square(a)
#     534 t, result_t = _commonType(a)
#     536 signature = 'D->D' if isComplexType(t) else 'd->d'
#
# File ~/.local/lib/python3.10/site-packages/numpy/linalg/linalg.py:190, in _assert_stacked_square(*arrays)
#     188 m, n = a.shape[-2:]
#     189 if m != n:
# --> 190     raise LinAlgError('Last 2 dimensions of the array must be square')
#
# LinAlgError: Last 2 dimensions of the array must be square

# %%
meshx = [[0,1,0],
         [],
         []]

meshy = [[0,0,1], 
         [],
         []]


print(meshy)
# Out:
# [[0, 0, 1]]

# %%
# x = np.arange(0, 2, 1)
# y = np.arange(0, 2, 1)
# X, Y = np.meshgrid(x, y)
# plt.scatter(X, Y)
# plt.scatter(2.3, 2.3)

# for n,m in zip(X,Y):
#     plt.plot([n, n+1, n, n], [m, m, m+1, m])
#     plt.plot([n+1, n, n+1, n+1], [m+1, m+1, m, m+1])

# %%
if 1 % 2 == 1: print("ho")
# Out:
# ho
